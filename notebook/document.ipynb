# %% [markdown]
# # Sample example of Document Structure

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is a document to show the Document Structure.",
    metadata={"source": "notebook", 
              "author": "LangChain",
              "date_created": "2026-08-12"},
)

# %%
doc
# Out:
# Document(metadata={'source': 'notebook', 'author': 'LangChain', 'date_created': '2026-08-12'}, page_content='This is a document to show the Document Structure.')
